# %%
# Code partially generated with the help of ChatGPT (OpenAI, 2025)
# https://www.openai.com/chatgpt

# Code partially generated with the help of CS50.ai (Harvard University, 2025)
# https://www.cs50.ai/chat

# I would like to express my gratitude to the creators and contributors of the libraries and code editor notebooks used in this project. Please read the README.md file in my repository to see the copyright licenses attached.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('shuffledLabeledSQJtrain.csv')
X = data.iloc[:, :-1:].values
y = data.iloc[:, 0].values

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
val_data = pd.read_csv('shuffledlabeledSQJval.csv')
X_val = val_data.iloc[:, :-1:].values
y_val = val_data.iloc[:, 0].values

# %%
# Use to debug!
# print("Training labels:", np.unique(y))
# print("Validation labels:", np.unique(y_val))
# print(f"Is _ in y? {'1' in y}")
# print(f"Is _ in y_val? {'1' in y_val}")
# unseen_labels = set(y_val) - set(label_encoder.classes_)
# if unseen_labels:
     # print(f"Unseen labels in validation set: {unseen_labels}")

# %%
batch_sizes = [4, 8, 16, 32]
history_dicts = {}

# %%
for batch_size in batch_sizes:
    print(f"Training with batch size: {batch_size}")
   
    model = Sequential([
            Dense(units=40, activation='sigmoid', input_dim=X.shape[1]),
            Dense(units=1, activation='sigmoid')
    ])
   
    model.compile(loss='binary_crossentropy', optimizer=SGD(learning_rate=0.1), metrics=['accuracy'])
       
    history = model.fit(X, y, epochs=10, batch_size=batch_size, validation_data=(X_val, y_val))
    history_dicts[batch_size] = history.history
# Out:
# Training with batch size: 4
# /home/platobearodog/CYSF_Project/myenv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9846 - loss: 0.2310 - val_accuracy: 1.0000 - val_loss: 0.1657
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9786 - loss: 0.1618 - val_accuracy: 1.0000 - val_loss: 0.0415
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9785 - loss: 0.0895 - val_accuracy: 1.0000 - val_loss: 0.0564
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9564 - loss: 0.0328 - val_accuracy: 0.9899 - val_loss: 0.1071
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9771 - loss: -0.0137 - val_accuracy: 0.9899 - val_loss: 0.0801
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9600 - loss: -0.0807 - val_accuracy: 0.9596 - val_loss: 0.1034
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9484 - loss: -0.1017 - val_accuracy: 0.9798 - val_loss: 0.0699
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9376 - loss: -0.0903 - val_accuracy: 0.9394 - val_loss: 0.1351
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9513 - loss: -0.0443 - val_accuracy: 0.9394 - val_loss: 0.1485
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9504 - loss: -0.0456 - val_accuracy: 0.9192 - val_loss: 0.1830
# Training with batch size: 8
# Epoch 1/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.8395 - loss: 0.4406 - val_accuracy: 1.0000 - val_loss: 0.1119
# Epoch 2/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9649 - loss: 0.3163 - val_accuracy: 1.0000 - val_loss: 0.0607
# Epoch 3/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9823 - loss: 0.1695 - val_accuracy: 1.0000 - val_loss: 0.0821
# Epoch 4/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9847 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.1369
# Epoch 5/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9819 - loss: 0.0925 - val_accuracy: 1.0000 - val_loss: 0.0766
# Epoch 6/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9817 - loss: 0.0644 - val_accuracy: 1.0000 - val_loss: 0.0959
# Epoch 7/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9728 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 0.1001
# Epoch 8/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9844 - loss: 0.0092 - val_accuracy: 0.9596 - val_loss: 0.1685
# Epoch 9/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9591 - loss: -0.1590 - val_accuracy: 1.0000 - val_loss: 0.0946
# Epoch 10/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9804 - loss: -0.0571 - val_accuracy: 0.9596 - val_loss: 0.1299
# Training with batch size: 16
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6023 - loss: 0.6817 - val_accuracy: 1.0000 - val_loss: 0.1191
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9808 - loss: 0.2183 - val_accuracy: 1.0000 - val_loss: 0.1268
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9814 - loss: 0.1817 - val_accuracy: 1.0000 - val_loss: 0.1135
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9784 - loss: 0.2006 - val_accuracy: 1.0000 - val_loss: 0.0963
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9729 - loss: 0.1828 - val_accuracy: 1.0000 - val_loss: 0.1004
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9609 - loss: 0.1972 - val_accuracy: 1.0000 - val_loss: 0.0858
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9683 - loss: 0.1518 - val_accuracy: 1.0000 - val_loss: 0.0855
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9853 - loss: 0.1133 - val_accuracy: 0.9899 - val_loss: 0.1048
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9656 - loss: 0.0871 - val_accuracy: 0.9899 - val_loss: 0.0897
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9570 - loss: 0.1140 - val_accuracy: 1.0000 - val_loss: 0.0833
# Training with batch size: 32
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8208 - loss: 0.5849 - val_accuracy: 1.0000 - val_loss: 0.1568
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9619 - loss: 0.3320 - val_accuracy: 1.0000 - val_loss: 0.1017
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9679 - loss: 0.2545 - val_accuracy: 1.0000 - val_loss: 0.0887
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9800 - loss: 0.2261 - val_accuracy: 1.0000 - val_loss: 0.0838
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9775 - loss: 0.2176 - val_accuracy: 1.0000 - val_loss: 0.0873
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9666 - loss: 0.2572 - val_accuracy: 1.0000 - val_loss: 0.1007
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9777 - loss: 0.2408 - val_accuracy: 1.0000 - val_loss: 0.0888
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9733 - loss: 0.2082 - val_accuracy: 1.0000 - val_loss: 0.0830
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9735 - loss: 0.1659 - val_accuracy: 1.0000 - val_loss: 0.1081
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9810 - loss: 0.1449 - val_accuracy: 1.0000 - val_loss: 0.0965

# %%
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 2, 1)
for batch_size in batch_sizes:
    plt.plot(history_dicts[batch_size]['val_loss'], label=f'Batch size {batch_size}')
plt.xlabel('Epochs')
plt.ylabel('val_loss')
plt.title('Loss Curve Comparison(0.1)')
plt.legend()

# %%
plt.subplot(1, 2, 2)
for batch_size in batch_sizes:
    plt.plot(history_dicts[batch_size]['val_accuracy'], label=f'Batch size {batch_size}')
plt.xlabel('Epochs')
plt.ylabel('val_accuracy')
plt.title('Accuracy Curve Comparison(0.1)')
plt.legend()

# %%
plt.tight_layout()
plt.show()
